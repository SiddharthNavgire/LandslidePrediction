# %%
import pandas as pd

df = pd.read_csv("cleaned.csv")
df = df.drop('ID', axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0    aspect   strdist  basarea  basin  curvature  curve_cont  \
# 0           2  265.2971  644.9806    65600      1  -2.156464    0.636057
# 1           3  267.3936  647.7654    65600      1   2.616730   -2.301352
# 2           6  272.0991  625.1400    65600      1   0.029022   -0.073801
# 3           7  272.9689  628.0128    65600      1  -1.793457    0.881960
# 4           8  261.2346  631.5062    65600      1   2.723572   -2.240553
#
#    curve_prof    curves  drop  ...      elev  cohesion  slide  scarpdist  \
# 0   -1.520407  0.214373  25.0  ...  1057.005        10      1   28.28427
# 1    0.315377  0.135763  40.0  ...  1065.420        10      1   20.00000
# 2   -0.044779  0.164955  25.0  ...  1058.138        10      1   20.00000
# 3   -0.911497  0.215654  25.0  ...  1063.369        10      1   20.00000
# 4    0.483019  0.142164  42.5  ...  1072.220        10      1   20.00000
#
#    scarps  frictang     slope  slopeleg  woods  specwt
# ...

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.head()
# Out:
#      aspect   strdist  basarea  basin  curvature  curve_cont  curve_prof  \
# 0  265.2971  644.9806    65600      1  -2.156464    0.636057   -1.520407
# 1  267.3936  647.7654    65600      1   2.616730   -2.301352    0.315377
# 2  272.0991  625.1400    65600      1   0.029022   -0.073801   -0.044779
# 3  272.9689  628.0128    65600      1  -1.793457    0.881960   -0.911497
# 4  261.2346  631.5062    65600      1   2.723572   -2.240553    0.483019
#
#      curves  drop  rockdist  ...      elev  cohesion  slide  scarpdist  \
# 0  0.214373  25.0         0  ...  1057.005        10      1   28.28427
# 1  0.135763  40.0         0  ...  1065.420        10      1   20.00000
# 2  0.164955  25.0         0  ...  1058.138        10      1   20.00000
# 3  0.215654  25.0         0  ...  1063.369        10      1   20.00000
# 4  0.142164  42.5         0  ...  1072.220        10      1   20.00000
#
#    scarps  frictang     slope  slopeleg  woods  specwt
# ...

# %%
df.columns
# Calculate mean for each column
mean_stats = df.mean()

# Calculate median for each column
median_stats = df.median()

# Calculate mode for each column
mode_stats = df.mode().iloc[0]  # Take the first row as mode

# Create a DataFrame with the calculated statistics
summary_stats = pd.DataFrame({'Mean': mean_stats, 'Median': median_stats, 'Mode': mode_stats})

# Format the DataFrame to display values without scientific notation
pd.set_option('display.float_format', '{:.4f}'.format)

# Print the result
print(summary_stats)
# Out:
#                    Mean       Median         Mode
# aspect         203.8226     210.4883     109.8051
# strdist         80.7205      56.5685      20.0000
# basarea    3233974.2801 5068000.0000 5068000.0000
# basin           19.2737      17.0000      17.0000
# curvature        0.0061       0.0209      -0.0832
# curve_cont       0.0178       0.0058      -0.3106
# curve_prof       0.0239       0.0318      -1.1039
# curves           0.1750       0.1561       0.0895
# drop            28.5217      23.3333      20.0000
# rockdist         0.0000       0.0000       0.0000
# flowdir         14.2487       8.0000       8.0000
# fos              2.0681       1.4090       0.5477
# lith             6.5851       3.0000       3.0000
# elev           925.2737     944.9959     939.9977
# cohesion        18.2316      10.0000      10.0000
# slide            0.3290       0.0000       0.0000
# scarpdist       59.3277      40.0000       0.0000
# scarps           0.2169       0.0000       0.0000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(style="whitegrid")
sns.relplot(x="aspect", y="slide", data=df, kind="line", height=6, aspect=1.5, ci=None)

plt.show()

# %%
sns.set(style="whitegrid")
sns.relplot(x="strdist", y="slide", data=df, kind="line", height=6, aspect=1.5, ci=None)

plt.show()

# %%
sns.set(style="whitegrid")
sns.relplot(x="basarea", y="slide", data=df, kind="line", height=6, aspect=1.5, ci=None)

plt.show()

# %%
df.columns
# Out:
# Index(['aspect', 'strdist', 'basarea', 'basin', 'curvature', 'curve_cont',
#        'curve_prof', 'curves', 'drop', 'rockdist', 'flowdir', 'fos', 'lith',
#        'elev', 'cohesion', 'slide', 'scarpdist', 'scarps', 'frictang', 'slope',
#        'slopeleg', 'woods', 'specwt'],
#       dtype='object')

# %%
sns.set(style="whitegrid")
sns.relplot(x="basin", y="slide", data=df, kind="line", height=6, aspect=1.5, ci=None)

plt.show()

# %%
sns.set(style="whitegrid")
sns.relplot(x="curvature", y="slide", data=df, kind="line", height=6, aspect=1.5, ci=None)

plt.show()

# %%
sns.set(style="whitegrid")
sns.relplot(x="curve_cont", y="slide", data=df, kind="line", height=6, aspect=1.5, ci=None)

plt.show()

# %%
sns.set(style="whitegrid")
sns.relplot(x="curve_prof", y="slide", data=df, kind="line", height=6, aspect=1.5, ci=None)

plt.show()

# %%
correlation_matrix = df.corr()

plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
